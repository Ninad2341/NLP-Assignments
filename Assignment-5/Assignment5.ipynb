# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.corpus import wordnet as wn
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
text = "The car is fast and the driver is happy"
words = text.lower().split()
words
# Out:
# ['the', 'car', 'is', 'fast', 'and', 'the', 'driver', 'is', 'happy']

# %%
def get_synonyms(word):
    synonyms = set()
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return synonyms

get_synonyms("fast")
# Out:
# {'debauched',
#  'degenerate',
#  'degraded',
#  'dissipated',
#  'dissolute',
#  'fast',
#  'fasting',
#  'firm',
#  'flying',
#  'immobile',
#  'libertine',
#  'loyal',
#  'profligate',
#  'quick',
#  'riotous',
#  'tight',
#  'truehearted'}

# %%
def get_antonyms(word):
    antonyms = set()
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())
    return antonyms

get_antonyms("happy")
# Out:
# {'unhappy'}

# %%
def get_hypernyms(word):
    hypernyms = set()
    for syn in wn.synsets(word):
        for hyper in syn.hypernyms():
            hypernyms.add(hyper.name())
    return hypernyms

get_hypernyms("car")
# Out:
# {'compartment.n.02', 'motor_vehicle.n.01', 'wheeled_vehicle.n.01'}

# %%
for word in words:
    print(f"\nWord: {word}")
    print("Synonyms:", get_synonyms(word))
    print("Antonyms:", get_antonyms(word))
    print("Hypernyms:", get_hypernyms(word))
# Out:
# Word: the
# Synonyms: set()
# Antonyms: set()
# Hypernyms: set()
#
# Word: car
# Synonyms: {'car', 'cable_car', 'railroad_car', 'auto', 'automobile', 'gondola', 'machine', 'elevator_car', 'railcar', 'railway_car', 'motorcar'}
# Antonyms: set()
# Hypernyms: {'motor_vehicle.n.01', 'compartment.n.02', 'wheeled_vehicle.n.01'}
#
# Word: is
# Synonyms: {'constitute', 'comprise', 'make_up', 'follow', 'personify', 'cost', 'exist', 'equal', 'represent', 'live', 'embody', 'be'}
# Antonyms: {'differ'}
# Hypernyms: {'be.v.01', 'typify.v.02', 'stay.v.01', 'take.v.02'}
#
# Word: fast
# Synonyms: {'truehearted', 'debauched', 'tight', 'firm', 'degenerate', 'dissolute', 'libertine', 'loyal', 'flying', 'quick', 'fasting', 'riotous', 'degraded', 'fast', 'profligate', 'immobile', 'dissipated'}
# Antonyms: {'slow'}
# Hypernyms: {'abstain.v.02', 'abstinence.n.02'}
#
# Word: and
# Synonyms: set()
# Antonyms: set()
# Hypernyms: set()
#
# Word: the
# Synonyms: set()
# Antonyms: set()
# Hypernyms: set()
#
# Word: driver
# Synonyms: {'number_one_wood', 'driver', 'device_driver'}
# Antonyms: {'nondriver'}
# Hypernyms: {'wood.n.08', 'worker.n.01', 'utility_program.n.01', 'operator.n.02', 'golfer.n.01'}
#
# Word: is
# Synonyms: {'constitute', 'comprise', 'make_up', 'follow', 'personify', 'cost', 'exist', 'equal', 'represent', 'live', 'embody', 'be'}
# Antonyms: {'differ'}
# Hypernyms: {'be.v.01', 'typify.v.02', 'stay.v.01', 'take.v.02'}
#
# Word: happy
# Synonyms: {'well-chosen', 'felicitous', 'glad', 'happy'}
# Antonyms: {'unhappy'}
# Hypernyms: set()
